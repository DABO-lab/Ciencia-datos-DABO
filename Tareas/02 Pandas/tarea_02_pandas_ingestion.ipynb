# %% [markdown]
# # Tarea 02 — Carga de Datos con Pandas
#
# **Instrucciones:** Completa cada celda de código con tu respuesta.
# Usarás el dataset de Iris disponible en la URL indicada.

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Parte 1 — Cargar y explorar datos

# %% [markdown]
# **P1.** Carga el dataset de Iris desde la siguiente URL y guárdalo en una variable llamada `df`.
# URL: `https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv`

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# Tu respuesta aquí

df = pd.read_csv(url)

# %% [markdown]
# **P2.** Muestra las primeras 5 filas del DataFrame.

# %%
# Tu respuesta aquí
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **P3.** Usa `.info()` para ver los tipos de columnas y si hay valores nulos.
# Luego usa `.describe()` para ver el resumen estadístico. ¿Cuántas filas tiene el dataset?

# %%
# Tu respuesta aquí

df.info()

df.describe()

df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB
# (150, 5)

# %% [markdown]
# **Respuesta:** El dataset tiene _150_ filas.

# %% [markdown]
# ---
# ## Parte 2 — Selección y filtrado

# %% [markdown]
# **P4.** Selecciona solo las columnas `sepal_length` y `species` e imprime las primeras 5 filas.

# %%
# Tu respuesta aquí
resultado = df[['sepal_length', 'species']]


print(resultado.head())
# Out:
#    sepal_length species
# 0           5.1  setosa
# 1           4.9  setosa
# 2           4.7  setosa
# 3           4.6  setosa
# 4           5.0  setosa

# %% [markdown]
# **P5.** Filtra el DataFrame para quedarte solo con las flores de la especie `virginica`.
# ¿Cuántas filas tiene ese subconjunto?

# %%
solo_virginica = df[df['species'] == 'virginica']

# 2. Contamos las filas usando len() o .shape[0]
cantidad_filas = len(solo_virginica)

print(f"El subconjunto de la especie virginica tiene {cantidad_filas} filas.")
# Out:
# El subconjunto de la especie virginica tiene 50 filas.

# %% [markdown]
# **P6.** Filtra las filas donde `petal_length` sea mayor a 5.0. Imprime cuántas filas cumplen esa condición.

# %%
# Tu respuesta aquí


petalos_grandes = df[df['petal_length'] > 5.0]

# Contamos cuántas filas resultaron del filtro
conteo = len(petalos_grandes)

print(f"Hay {conteo} filas donde petal_length es mayor a 5.0")
# Out:
# Hay 42 filas donde petal_length es mayor a 5.0

# %% [markdown]
# ---
# ## Parte 3 — Guardar datos

# %% [markdown]
# **P7.** Guarda el subconjunto de `virginica` (de P5) en un archivo CSV llamado `virginica.csv` en la carpeta `output/`.
# No incluyas el índice en el archivo guardado.

# %%
import os
os.makedirs("output", exist_ok=True)

# Tu respuesta aquí

# 1. Crear la carpeta 'output' si no existe para evitar errores
if not os.path.exists('output'):
    os.makedirs('output')

# 2. Guardar el DataFrame 'solo_virginica' (el que creaste en el paso P5)
solo_virginica.to_csv('output/virginica.csv', index=False)

print("Archivo guardado")
# Out:
# Archivo guardado

# %% [markdown]
# **P8.** Carga de nuevo el archivo `output/virginica.csv` y verifica que tiene el número correcto de filas usando `.shape`.

# %%
# Tu respuesta aquí

import csv
csv = 'output/virginica.csv'        
virginica_recargado = pd.read_csv(csv)

# 2. Verificar las dimensiones (filas, columnas)
dimensiones = virginica_recargado.shape

print(virginica_recargado.head(10))
print("--------------------------------------------------------------------")
print(f"Las dimensiones del archivo cargado son: {dimensiones}")
print(f"El número de filas es: {dimensiones[0]}")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0           6.3          3.3           6.0          2.5  virginica
# 1           5.8          2.7           5.1          1.9  virginica
# 2           7.1          3.0           5.9          2.1  virginica
# 3           6.3          2.9           5.6          1.8  virginica
# 4           6.5          3.0           5.8          2.2  virginica
# 5           7.6          3.0           6.6          2.1  virginica
# 6           4.9          2.5           4.5          1.7  virginica
# 7           7.3          2.9           6.3          1.8  virginica
# 8           6.7          2.5           5.8          1.8  virginica
# 9           7.2          3.6           6.1          2.5  virginica
# --------------------------------------------------------------------
# Las dimensiones del archivo cargado son: (50, 5)
# El número de filas es: 50

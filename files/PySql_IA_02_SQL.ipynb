# %% [markdown]
# # **OBJETIVOS DE ESTE CUADERNO**
#
# 1.  Utilizar SQLite como motor de base de datos dentro de colab para practicar operaciones SQL
#
# 2.  Realizar operaciones SQL de consulta sobre una tabla, N tablas y de agregación
#
# <br/>
#
# ---
#
# <br/>
#
# ## **NOTAS IMPORTANTES PARA USUARIOS EXPERIMENTADOS**
#
# En estos ejercicios se crean tablas sin relaciones, sin claves foráneas y otros conceptos relevantes. Dado que el objetivo de este cuaderno es practicar sentencias SQL tipo "select" y operaciones de agregación, se omiten este tipo de temas para enfocarse en el objetivo principal.
#
# Adicionalmente se utiliza sqlite como motor de bases de datos, primero por su simplicidad en cuanto a ejecutarse internamente en Colab, y segundo porque es suficiente para los objetivos de este cuaderno.

# %% [markdown]
# # **1. PREPARACIÓN DEL ENTORNO**

# %% [markdown]
# # **1.1 Importar librerías y módulos**

# %%
##########
# PANDAS #
##########
import pandas as pd

##########
# SQLITE #
##########
import sqlite3 as sql

# %% [markdown]
# # **2. PREPARACIÓN DE LOS DATOS**

# %% [markdown]
# # **2.1 Base de datos "world": Obtener los datos de las tablas "country", "city" y "country_language" desde url públicas y llevarlos a DataFrames**

# %%
url_country = 'https://raw.githubusercontent.com/navnebror/public_resources/refs/heads/main/databases/world2/country.csv'
url_city = 'https://raw.githubusercontent.com/navnebror/public_resources/refs/heads/main/databases/world2/city.csv'
url_language = 'https://raw.githubusercontent.com/navnebror/public_resources/refs/heads/main/databases/world2/country_language.csv'

df_country = pd.read_csv(url_country)
df_country.set_index('code', inplace=True)

df_city = pd.read_csv(url_city)
df_city.set_index('id', inplace=True)

df_language = pd.read_csv(url_language)
df_language.set_index(['country_code', 'language'], inplace=True)

# %% [markdown]
# # **2.2 Base de datos "chemistry": Obtener los datos de la tabla "elements" desde url públicas y llevarlos a DataFrames**

# %%
url_elements = 'https://raw.githubusercontent.com/navnebror/public_resources/refs/heads/main/databases/chemistry/elements.json'

df_elements = pd.read_json(url_elements)
df_elements.set_index('atomic_number', inplace=True)

# %% [markdown]
# # **2.3 Base de datos "art": Obtener los datos de la tabla "singers" desde url públicas y llevarlos a DataFrames**

# %%
url_singers = 'https://raw.githubusercontent.com/navnebror/public_resources/refs/heads/main/databases/art/singers.xml'

df_singers = pd.read_xml(url_singers)
df_singers.set_index('id', inplace=True)

# %% [markdown]
# # **2.4 Cargar los datos desde los DataFrame hacia una base de datos temporal llamada "test"**

# %%
conn = sql.connect(r'C:\Users\andre\Documents\Proyectos\Ciencia-datos-DABO\files\test.db')

conn.execute('drop table if exists country')
conn.execute('drop table if exists city')
conn.execute('drop table if exists country_language')
conn.execute('drop table if exists elements')
conn.execute('drop table if exists singers')

df_country.to_sql('country', conn)
df_city.to_sql('city', conn)
df_language.to_sql('country_language', conn)

df_elements.to_sql('elements', conn)

df_singers.to_sql('singers', conn)
# Out:
# 20

# %% [markdown]
# # **3. EJERCICIOS RESUELTOS: CONSULTAS SQL BÁSICAS**
#
# **NOTA: En estos ejercicios, los resultados siempre se llevan a un DataFrame**

# %% [markdown]
# # **3.1 Consultar los datos de todos los cantantes**

# %%
sentencia_sql = """

select  *
from    singers

"""

df = pd.read_sql(sentencia_sql, conn)
df.set_index('id', inplace=True)

print(df)
# Out:
#     first_name  last_name  birth_date      genre  gender heigth  awards
# id
# 1       SELENA      GOMEZ  1992-07-22        POP  FEMALE   1,65      15
# 2        BECKY          G  1997-03-02  REGGAETON  FEMALE   1,52       5
# 3        KAROL          G  1991-02-14  REGGAETON  FEMALE    1,7      10
# 4       TAYLOR      SWIFT  1989-12-13        POP  FEMALE    1,8      30
# 5       ARIANA     GRANDE  1993-06-26        POP  FEMALE   1,53      20
# 6          DUA       LIPA  1995-08-22        POP  FEMALE   1,65      18
# 7       CAMILA    CABELLO  1997-03-03        POP  FEMALE    1,6      12
# 8        SHAWN     MENDES  1998-08-08        POP    MALE   1,88      25
# 9       BILLIE     EILISH  2001-12-18        POP  FEMALE   1,61       8
# 10          ED    SHEERAN  1991-02-17        POP    MALE   1,73      22
# 11      JUSTIN     BIEBER  1994-03-01        POP    MALE   1,75      17
# 12     RIHANNA      FENTY  1988-02-20        R&B  FEMALE   1,73      30
# 13        KATY      PERRY  1984-10-25        POP  FEMALE    1,7      28
# 14       HARRY     STYLES  1994-02-01        POP    MALE    1,8      15
# 15  THE WEEKND    TESFAYE  1990-02-16        R&B    MALE   1,78      21
# 16     BEYONCE    KNOWLES  1981-09-04        R&B  FEMALE   1,69      27
# 17        ZAYN      MALIK  1993-01-12        POP    MALE   1,75      10
# 18       CARDI          B  1992-10-11    HIP HOP  FEMALE    1,6       8
# 19        POST     MALONE  1995-07-04    HIP HOP    MALE   1,84      12
# 20       LIZZO  JEFFERSON  1988-04-27        POP  FEMALE   1,78      14

# %% [markdown]
# # **3.2 Consultar los datos de todos los elementos químicos**

# %%
sentencia_sql = """

select  *
from    elements

"""

df = pd.read_sql(sentencia_sql, conn)
df.set_index('name', inplace=True)

print(df)
# Out:
#              atomic_number symbol  family  period  atomic_mass     density  \
# name
# HYDROGEN                 1      H     1.0       1  1008.000000    0.000090
# HELIUM                   2     HE    18.0       1     4.002602    0.000179
# LITHIUM                  3     LI     1.0       2     6.940000  534.000000
# NERYLLIUM                4     BE     2.0       2     9.012183    1.850000
# BORON                    5      B    13.0       2    10.810000    2.340000
# ...                    ...    ...     ...     ...          ...         ...
# FLEROVIUM              114     FL    14.0       7   289.000000   14.000000
# MOSCOVIUM              115     MC    15.0       7   289.000000   13.500000
# LIVERMORIUM            116     LV    16.0       7   293.000000   12.900000
# TENNESSINE             117     TS    17.0       7   294.000000    7.200000
# OGANESSON              118     OG    18.0       7   294.000000    5.000000
#
#              melting_point  boiling_point  thermal_capacity  \
# name
# HYDROGEN           -259.14        -252.87           14304.0
# HELIUM             -272.20        -268.93            5193.0
# LITHIUM             180.54        1286.85            3582.0
# NERYLLIUM          1286.85        2468.85            1825.0
# BORON              2075.85        3926.85            1026.0
# ...                    ...            ...               ...
# FLEROVIUM            66.85         146.85               NaN
# MOSCOVIUM           426.85        1126.85               NaN
# LIVERMORIUM         435.35         811.85               NaN
# TENNESSINE          449.85         609.85               NaN
# OGANESSON           -15.15         -10.15               NaN
#
#              electronegativity  discovery_year        discoverers  \
# name
# HYDROGEN                  2.20            1766    HENRY CAVENDISH
# HELIUM                     NaN            1895     RAMSAY Y CLEVE
# LITHIUM                   0.98            1817          ARFWEDSON
# NERYLLIUM                 1.57            1797          VAUQUELIN
# BORON                     2.04            1808  DAVY Y GAY-LUSSAC
# ...                        ...             ...                ...
# FLEROVIUM                  NaN            1999               JINR
# MOSCOVIUM                  NaN            2004               JINR
# LIVERMORIUM                NaN            2006         JINR, LLNL
# TENNESSINE                 NaN            2009               JINR
# OGANESSON                  NaN            2006         JINR, LLNL
#
#                                       electronic_configuration  \
# name
# HYDROGEN                                                   1s1
# HELIUM                                                     1s2
# LITHIUM                                                1s2 2s1
# NERYLLIUM                                              1s2 2s2
# BORON                                              1s2 2s2 2p1
# ...                                                        ...
# FLEROVIUM    1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# MOSCOVIUM    1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# LIVERMORIUM  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# TENNESSINE   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# OGANESSON    1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
#
#             electronic_configuration_small name_spanish
# name
# HYDROGEN                               1s1    HIDROGENO
# HELIUM                                 1s2        HELIO
# LITHIUM                           [HE] 2s1        LITIO
# NERYLLIUM                         [HE] 2s2      BERILIO
# BORON                         [HE] 2s2 2p1         BORO
# ...                                    ...          ...
# FLEROVIUM           [RN] 7s2 5f14 6d10 7p2     FLEROVIO
# MOSCOVIUM           [RN] 7s2 5f14 6d10 7p3     MOSCOVIO
# LIVERMORIUM         [RN] 7s2 5f14 6d10 7p4   LIVERMORIO
# TENNESSINE          [RN] 7s2 5f14 6d10 7p5       TENESO
# OGANESSON           [RN] 7s2 5f14 6d10 7p6     OGANESON
#
# [118 rows x 15 columns]

# %% [markdown]
# # **3.3 Consultar los datos de todos los países**

# %%
sentencia_sql = """

select  *
from    country

"""

df = pd.read_sql(sentencia_sql, conn)
df.set_index('code', inplace=True)

print(df)
# Out:
#               name      continent                     region  surface_area  \
# code
# ABW          Aruba  North America                  Caribbean         193.0
# AFG    Afghanistan           Asia  Southern and Central Asia      652090.0
# AGO         Angola         Africa             Central Africa     1246700.0
# AIA       Anguilla  North America                  Caribbean          96.0
# ALB        Albania         Europe            Southern Europe       28748.0
# ...            ...            ...                        ...           ...
# YEM          Yemen           Asia                Middle East      527968.0
# YUG     Yugoslavia         Europe            Southern Europe      102173.0
# ZAF   South Africa         Africa            Southern Africa     1221037.0
# ZMB         Zambia         Africa             Eastern Africa      752618.0
# ZWE       Zimbabwe         Africa             Eastern Africa      390757.0
#
#       independence_year  population  life_expectancy       gnp   gnp_old  \
# code
# ABW                 NaN      103000             78.4     828.0     793.0
# AFG              1919.0    22720000             45.9    5976.0       NaN
# AGO              1975.0    12878000             38.3    6648.0    7984.0
# AIA                 NaN        8000             76.1      63.2       NaN
# ALB              1912.0     3401200             71.6    3205.0    2500.0
# ...                 ...         ...              ...       ...       ...
# YEM              1918.0    18112000             59.8    6041.0    5729.0
# YUG              1918.0    10640000             72.4   17000.0       NaN
# ZAF              1910.0    40377000             51.1  116729.0  129092.0
# ZMB              1964.0     9169000             37.2    3377.0    3922.0
# ZWE              1980.0    11669000             37.8    5951.0    8670.0
#
#                  local_name                               government_form  \
# code
# ABW                   Aruba  Nonmetropolitan Territory of The Netherlands
# AFG   Afganistan/Afqanestan                               Islamic Emirate
# AGO                  Angola                                      Republic
# AIA                Anguilla                 Dependent Territory of the UK
# ALB               Shqiperia                                      Republic
# ...                     ...                                           ...
# YEM                Al-Yaman                                      Republic
# YUG             Jugoslavija                              Federal Republic
# ZAF            South Africa                                      Republic
# ZMB                  Zambia                                      Republic
# ZWE                Zimbabwe                                      Republic
#
#                 head_of_state  capital code2
# code
# ABW                   Beatrix    129.0    AW
# AFG             Mohammad Omar      1.0    AF
# AGO   Jose Eduardo dos Santos     56.0    AO
# AIA              Elisabeth II     62.0    AI
# ALB            Rexhep Mejdani     34.0    AL
# ...                       ...      ...   ...
# YEM        Ali Abdallah Salih   1780.0    YE
# YUG        Vojislav Kostunica   1792.0    YU
# ZAF               Thabo Mbeki    716.0    ZA
# ZMB         Frederick Chiluba   3162.0    ZM
# ZWE          Robert G. Mugabe   4068.0    ZW
#
# [239 rows x 14 columns]

# %% [markdown]
# # **3.4 Consultar los datos de todas las ciudades**

# %%
sentencia_sql = """

select  *
from    city

"""

df = pd.read_sql(sentencia_sql, conn)
df.set_index('id', inplace=True)

print(df)
# Out:
#                 name country_code       district  population
# id
# 1              Kabul          AFG          Kabol     1780000
# 2           Qandahar          AFG       Qandahar      237500
# 3              Herat          AFG          Herat      186800
# 4     Mazar-e-Sharif          AFG          Balkh      127800
# 5          Amsterdam          NLD  Noord-Holland      731200
# ...              ...          ...            ...         ...
# 4075      Khan Yunis          PSE     Khan Yunis      123175
# 4076          Hebron          PSE         Hebron      119401
# 4077        Jabaliya          PSE     North Gaza      113901
# 4078          Nablus          PSE         Nablus      100231
# 4079           Rafah          PSE          Rafah       92020
#
# [4079 rows x 4 columns]

# %% [markdown]
# # **3.5 Consultar los datos de todos los idiomas**

# %%
sentencia_sql = """

select  *
from    country_language

"""

df = pd.read_sql(sentencia_sql, conn)

print(df)
# Out:
#     country_code    language is_official  percentage
# 0            ABW       Dutch           T         5.3
# 1            ABW     English           F         9.5
# 2            ABW  Papiamento           F        76.7
# 3            ABW     Spanish           F         7.4
# 4            AFG     Balochi           F         0.9
# ..           ...         ...         ...         ...
# 979          ZMB       Tonga           F        11.0
# 980          ZWE     English           T         2.2
# 981          ZWE     Ndebele           F        16.2
# 982          ZWE      Nyanja           F         2.2
# 983          ZWE       Shona           F        72.1
#
# [984 rows x 4 columns]

# %% [markdown]
# # **3.6 Consultar las ciudades de Noruega y Suiza**

# %%
sentencia_sql = """

select  country.name,
        city.name
from    country,
        city
where   country.code = city.country_code
and     country.name IN ('Norway','Switzerland')

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#           name       name
# 0       Norway       Oslo
# 1       Norway     Bergen
# 2       Norway  Trondheim
# 3       Norway  Stavanger
# 4       Norway     Baerum
# 5  Switzerland     Zurich
# 6  Switzerland     Geneve
# 7  Switzerland      Basel
# 8  Switzerland       Bern
# 9  Switzerland   Lausanne

# %% [markdown]
# # **3.7 Consultar los idiomas oficiales y no oficiales que se hablan en Noruega y Suiza**

# %%
sentencia_sql = """

select  country.name,
        country_language.language,
        country_language.is_official
from    country,
        country_language
where   country.code = country_language.country_code
and     country.name IN ('Norway','Switzerland')

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#           name   language is_official
# 0  Switzerland     French           T
# 1  Switzerland     German           T
# 2  Switzerland    Italian           T
# 3  Switzerland    Romansh           T
# 4       Norway     Danish           F
# 5       Norway    English           F
# 6       Norway  Norwegian           T
# 7       Norway      Saame           F
# 8       Norway    Swedish           F

# %% [markdown]
# # **4. EJERCICIOS PARA RESOLVER: CONSULTAS SQL SOBRE UNA TABLA**
#
# En estos ejercicios, únicamente debe escribirse la sentencia SQL y ejecutar la celda. No debe cambiarse nada del código de Python

# %% [markdown]
# # **4.1 Mostrar nombre en inglés y en español, símbolo, número atómico, masa atómica, punto de fusión y punto de ebullición para los elementos con masa atómica entre 10 y 100**

# %%
sentencia_sql = """

select  name,
        name_spanish,
        symbol,
        atomic_number,
        atomic_mass,
        melting_point,
        boiling_point
from    elements
where   atomic_mass between 10 and 100

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#           name name_spanish symbol  atomic_number  atomic_mass  melting_point  \
# 0        BORON         BORO      B              5    10.810000        2075.85
# 1     FLUORINE        FLUOR      F              9    18.998403        -219.62
# 2         NEON         NEON     NE             10    20.179700        -248.59
# 3       SODIUM        SODIO     NA             11    22.989769          97.72
# 4    ALUMINIUM     ALUMINIO     AL             13    26.981538         660.32
# 5   PHOSPHORUS      FOSFORO      P             15    30.973762          44.15
# 6       SULFUR       AZUFRE      S             16    32.060000         115.21
# 7     CHLORINE        CLORO     CL             17    35.450000        -101.55
# 8    POTASSIUM      POTASIO      K             19    39.098300          63.38
# 9     SCANDIUM     ESCANDIO     SC             21    44.955908        1540.85
# 10    VANADIUM      VANADIO      V             23    50.941500        1909.85
# 11    CHROMIUM        CROMO     CR             24    51.996100        1906.85
# 12   MANGANESE    MANGANESO     MN             25    54.938044        1245.85
# 13      COBALT      COBALTO     CO             27    58.933194            NaN
# 14      NICKEL       NIQUEL     NI             28    58.693400        1454.85
# 15        ZINC         ZINC     ZN             30    65.380000         419.73
# 16     ARSENIC     ARSENICO     AS             33    74.921595         816.85
# 17    RUBIDIUM      RUBIDIO     RB             37    85.467800          39.31
# 18   STRONTIUM    ESTRONCIO     SR             38    87.620000         776.85
# 19     YTTRIUM        YTRIO      Y             39    88.905840        1525.85
# 20     NIOBIUM       NIOBIO     NB             41    92.906370        2476.85
# 21  MOLYBDENUM    MOLIBDENO     MO             42    95.950000        2622.85
# 22  TECHNETIUM     TECNECIO     TC             43    98.000000        2156.85
#
#     boiling_point
# 0         3926.85
# 1         -188.12
# 2         -246.08
# 3          882.85
# 4         2518.85
# 5          276.85
# 6          444.72
# 7          -34.04
# 8          758.85
# 9         2835.85
# 10        3406.85
# 11        2670.85
# 12        2060.85
# 13        2926.85
# 14        2912.85
# 15         906.85
# 16         613.85
# 17         687.85
# 18        1381.85
# 19        3335.85
# 20        4743.85
# 21        4638.85
# 22        4264.85

# %% [markdown]
# # **4.2 Mostrar nombre en inglés y en español, símbolo, número atómico, masa atómica, punto de fusión y punto de ebullición para los elementos con masa atómica entre 10 y 100 y con punto de ebullición menor a 0**

# %%
sentencia_sql = """

select  name,
        name_spanish,
        symbol,
        atomic_number,
        atomic_mass,
        melting_point,
        boiling_point
from    elements
where   atomic_mass between 10 and 100
and     boiling_point < 0

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#        name name_spanish symbol  atomic_number  atomic_mass  melting_point  \
# 0  FLUORINE        FLUOR      F              9    18.998403        -219.62
# 1      NEON         NEON     NE             10    20.179700        -248.59
# 2  CHLORINE        CLORO     CL             17    35.450000        -101.55
#
#    boiling_point
# 0        -188.12
# 1        -246.08
# 2         -34.04

# %% [markdown]
# # **4.3 Mostrar nombre en inglés y en español, símbolo y número atómico para los elementos con 4 órbitas (períodos)**

# %%
sentencia_sql = """

select  name,
        name_spanish,
        symbol,
        atomic_number
from    elements
where   period = 4

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#          name name_spanish symbol  atomic_number
# 0   POTASSIUM      POTASIO      K             19
# 1     CALCIUM       CALCIO     CA             20
# 2    SCANDIUM     ESCANDIO     SC             21
# 3    TITANIUM      TITANIO     TI             22
# 4    VANADIUM      VANADIO      V             23
# 5    CHROMIUM        CROMO     CR             24
# 6   MANGANESE    MANGANESO     MN             25
# 7        IRON       HIERRO     FE             26
# 8      COBALT      COBALTO     CO             27
# 9      NICKEL       NIQUEL     NI             28
# 10     COPPER        COBRE     CU             29
# 11       ZINC         ZINC     ZN             30
# 12    GALLIUM        GALIO     GA             31
# 13  GERMANIUM     GERMANIO     GE             32
# 14    ARSENIC     ARSENICO     AS             33
# 15   SELENIUM      SELENIO     SE             34
# 16    BROMINE        BROMO     BR             35
# 17    KRYPTON      KRIPTON     KR             36

# %% [markdown]
# # **4.4 Mostrar nombre en español, símbolo, número atómico y configuración electrónica completa (no la reducida) para los elementos punto de fusión desconocido o punto de ebullición desconocido**

# %%
sentencia_sql = """

select  name_spanish,
        symbol,
        atomic_number,
        electronic_configuration
from    elements
where   melting_point is null
or      boiling_point is null

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    name_spanish symbol  atomic_number  \
# 0       COBALTO     CO             27
# 1        FERMIO     FM            100
# 2    MENDELEVIO     MD            101
# 3       NOBELIO     NO            102
# 4     LAURENCIO     LR            103
# 5        DUBNIO     DB            105
# 6     SEABORGIO     SG            106
# 7        BOHRIO     BH            107
# 8        HASSIO     HS            108
# 9     MEITNERIO     MT            109
# 10  DARMSTADTIO     DS            110
# 11   ROENTGENIO     RG            111
# 12   COPERNICIO     CN            112
#
#                              electronic_configuration
# 0                         1s2 2s2 2p6 3s2 3p6 4s2 3d7
# 1   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 2   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 3   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 4   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 5   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 6   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 7   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 8   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 9   1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 10  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 11  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 12  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...

# %% [markdown]
# # **4.5 Mostrar el total de elementos por cantidad de órbitas (es decir, tantos elementos tienen tantas órbitas)**

# %%
sentencia_sql = """

select  period,
        count(*) as total_elementos
from    elements
group by period

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    period  total_elementos
# 0       1                2
# 1       2                8
# 2       3                8
# 3       4               18
# 4       5               18
# 5       6               32
# 6       7               32

# %% [markdown]
# # **4.6 Mostrar todos los datos disponibles para los elementos que comiencen con la letra H**

# %%
sentencia_sql = """

select  *
from    elements
where   name like 'H%'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    atomic_number symbol      name  family  period  atomic_mass      density  \
# 0              1      H  HYDROGEN     1.0       1  1008.000000     0.000090
# 1              2     HE    HELIUM    18.0       1     4.002602     0.000179
# 2             67     HO   HOLMIUM     NaN       6   164.930330  8795.000000
# 3             72     HF   HAFNIUM     4.0       6   178.490000    13.310000
# 4            108     HS   HASSIUM     8.0       7   269.000000    40.700000
#
#    melting_point  boiling_point  thermal_capacity  electronegativity  \
# 0        -259.14        -252.87           14304.0               2.20
# 1        -272.20        -268.93            5193.0                NaN
# 2        1460.85        2719.85             165.0               1.23
# 3        2232.85        4602.85             144.0               1.30
# 4            NaN            NaN               NaN                NaN
#
#    discovery_year         discoverers  \
# 0            1766     HENRY CAVENDISH
# 1            1895      RAMSAY Y CLEVE
# 2            1878               SORET
# 3            1923  COSTER Y DE HEVESY
# 4            1984             GSI (*)
#
#                             electronic_configuration  \
# 0                                                1s1
# 1                                                1s2
# 2  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 3  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
# 4  1s2 2s2 2p6 3s2 3p6 4s2 3d10 4p6 5s2 4d10 5p6 ...
#
#   electronic_configuration_small name_spanish
# 0                            1s1    HIDROGENO
# 1                            1s2        HELIO
# 2                  [XE] 6s2 4f11       HOLMIO
# 3              [XE] 6s2 4f14 5d2       HAFNIO
# 4              [RN] 7s2 5f14 6d6       HASSIO

# %% [markdown]
# # **4.7 Mostrar todos los datos disponibles para los elementos que comiencen con la letra H y que terminen con la letra O**

# %%
sentencia_sql = """

select  *
from    elements
where   name like 'H%O'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
# Empty DataFrame
# Columns: [atomic_number, symbol, name, family, period, atomic_mass, density, melting_point, boiling_point, thermal_capacity, electronegativity, discovery_year, discoverers, electronic_configuration, electronic_configuration_small, name_spanish]
# Index: []

# %% [markdown]
# # **4.8 Mostrar nombre, apellido y fecha de nacimiento de los cantantes de POP**

# %%
sentencia_sql = """

select  first_name,
        last_name,
        birth_date
from    singers
where   genre = 'POP'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    first_name  last_name  birth_date
# 0      SELENA      GOMEZ  1992-07-22
# 1      TAYLOR      SWIFT  1989-12-13
# 2      ARIANA     GRANDE  1993-06-26
# 3         DUA       LIPA  1995-08-22
# 4      CAMILA    CABELLO  1997-03-03
# 5       SHAWN     MENDES  1998-08-08
# 6      BILLIE     EILISH  2001-12-18
# 7          ED    SHEERAN  1991-02-17
# 8      JUSTIN     BIEBER  1994-03-01
# 9        KATY      PERRY  1984-10-25
# 10      HARRY     STYLES  1994-02-01
# 11       ZAYN      MALIK  1993-01-12
# 12      LIZZO  JEFFERSON  1988-04-27

# %% [markdown]
# # **4.9 Mostrar nombre, apellido y fecha de nacimiento de los cantantes de POP o de REGGAETON**

# %%
sentencia_sql = """

select  first_name,
        last_name,
        birth_date
from    singers
where   genre in ('POP', 'REGGAETON')

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    first_name  last_name  birth_date
# 0      SELENA      GOMEZ  1992-07-22
# 1       BECKY          G  1997-03-02
# 2       KAROL          G  1991-02-14
# 3      TAYLOR      SWIFT  1989-12-13
# 4      ARIANA     GRANDE  1993-06-26
# 5         DUA       LIPA  1995-08-22
# 6      CAMILA    CABELLO  1997-03-03
# 7       SHAWN     MENDES  1998-08-08
# 8      BILLIE     EILISH  2001-12-18
# 9          ED    SHEERAN  1991-02-17
# 10     JUSTIN     BIEBER  1994-03-01
# 11       KATY      PERRY  1984-10-25
# 12      HARRY     STYLES  1994-02-01
# 13       ZAYN      MALIK  1993-01-12
# 14      LIZZO  JEFFERSON  1988-04-27

# %% [markdown]
# # **4.10 Mostrar la cantidad total de premios que han ganado los cantantes de POP**

# %%
sentencia_sql = """

select  sum(awards) as total_premios
from    singers
where   genre = 'POP'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    total_premios
# 0            234

# %% [markdown]
# # **4.11 Mostrar la cantidad total de premios que han ganado los cantantes por cada género musical**

# %%
sentencia_sql = """

select  genre,
        sum(awards) as total_premios
from    singers
group by genre

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#        genre  total_premios
# 0    HIP HOP             20
# 1        POP            234
# 2        R&B             78
# 3  REGGAETON             15

# %% [markdown]
# # **4.12 Mostrar cuantos cantantes son mujeres y cuantos hombres**

# %%
sentencia_sql = """

select  gender,
        count(*) as cantidad
from    singers
group by gender

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#    gender  cantidad
# 0  FEMALE        13
# 1    MALE         7

# %% [markdown]
# # **5. EJERCICIOS PARA RESOLVER: CONSULTAS SQL SOBRE VARIAS TABLAS**
#
# En estos ejercicios, únicamente debe escribirse la sentencia SQL y ejecutar la celda. No debe cambiarse nada del código de Python

# %% [markdown]
# # **5.1 Mostrar nombre de ciudad, nombre de país y continente del país para los países de la región Caribe (en la base de datos se identifica como región "Caribbean")**

# %%
sentencia_sql = """

select  city.name as ciudad,
        country.name as pais,
        country.continent
from    city,
        country
where   city.country_code = country.code
and     country.region = 'Caribbean'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#                         ciudad                              pais  \
# 0                   Willemstad              Netherlands Antilles
# 1                   South Hill                          Anguilla
# 2                   The Valley                          Anguilla
# 3                  Saint Johns               Antigua and Barbuda
# 4                   Oranjestad                             Aruba
# 5                       Nassau                           Bahamas
# 6                   Bridgetown                          Barbados
# 7                    Road Town           Virgin Islands, British
# 8                  George Town                    Cayman Islands
# 9                       Roseau                          Dominica
# 10     Santo Domingo de Guzman                Dominican Republic
# 11  Santiago de los Caballeros                Dominican Republic
# 12                   La Romana                Dominican Republic
# 13        San Pedro de Macoris                Dominican Republic
# 14    San Francisco de Macoris                Dominican Republic
# 15  San Felipe de Puerto Plata                Dominican Republic
# 16               Saint Georges                           Grenada
# 17                  Les Abymes                        Guadeloupe
# 18                 Basse-Terre                        Guadeloupe
# 19              Port-au-Prince                             Haiti
# 20                   Carrefour                             Haiti
# 21                      Delmas                             Haiti
# 22              Le-Cap-Haitien                             Haiti
# 23                Spanish Town                           Jamaica
# 24                    Kingston                           Jamaica
# 25                    Portmore                           Jamaica
# 26                   La Habana                              Cuba
# 27            Santiago de Cuba                              Cuba
# 28                    Camaguey                              Cuba
# 29                     Holguin                              Cuba
# 30                 Santa Clara                              Cuba
# 31                  Guantanamo                              Cuba
# 32               Pinar del Rio                              Cuba
# 33                      Bayamo                              Cuba
# 34                  Cienfuegos                              Cuba
# 35       Victoria de las Tunas                              Cuba
# 36                    Matanzas                              Cuba
# 37                  Manzanillo                              Cuba
# 38             Sancti-Spiritus                              Cuba
# 39              Ciego de Ávila                              Cuba
# 40              Fort-de-France                        Martinique
# 41                    Plymouth                        Montserrat
# 42                    San Juan                       Puerto Rico
# 43                     Bayamon                       Puerto Rico
# 44                       Ponce                       Puerto Rico
# 45                    Carolina                       Puerto Rico
# 46                      Caguas                       Puerto Rico
# 47                     Arecibo                       Puerto Rico
# 48                    Guaynabo                       Puerto Rico
# 49                    Mayaguez                       Puerto Rico
# 50                    Toa Baja                       Puerto Rico
# 51                  Basseterre             Saint Kitts and Nevis
# 52                    Castries                       Saint Lucia
# 53                   Kingstown  Saint Vincent and the Grenadines
# 54                   Chaguanas               Trinidad and Tobago
# 55               Port-of-Spain               Trinidad and Tobago
# 56               Cockburn Town          Turks and Caicos Islands
# 57            Charlotte Amalie              Virgin Islands, U.S.
#
#         continent
# 0   North America
# 1   North America
# 2   North America
# 3   North America
# 4   North America
# 5   North America
# 6   North America
# 7   North America
# 8   North America
# 9   North America
# 10  North America
# 11  North America
# 12  North America
# 13  North America
# 14  North America
# 15  North America
# 16  North America
# 17  North America
# 18  North America
# 19  North America
# 20  North America
# 21  North America
# 22  North America
# 23  North America
# 24  North America
# 25  North America
# 26  North America
# 27  North America
# 28  North America
# 29  North America
# 30  North America
# 31  North America
# 32  North America
# 33  North America
# 34  North America
# 35  North America
# 36  North America
# 37  North America
# 38  North America
# 39  North America
# 40  North America
# 41  North America
# 42  North America
# 43  North America
# 44  North America
# 45  North America
# 46  North America
# 47  North America
# 48  North America
# 49  North America
# 50  North America
# 51  North America
# 52  North America
# 53  North America
# 54  North America
# 55  North America
# 56  North America
# 57  North America

# %% [markdown]
# # **5.2 Mostrar nombre de país y nombre del idioma para los idiomas no oficiales que se hablan en américa del sur (en la base de datos se identifica como continente con nombre "South America")**

# %%
sentencia_sql = """

select  country.name as pais,
        country_language.language as idioma
from    country,
        country_language
where   country.code = country_language.country_code
and     country.continent = 'South America'
and     country_language.is_official = 'F'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#              pais            idioma
# 0       Argentina  Indian Languages
# 1       Argentina           Italian
# 2         Bolivia           Guarani
# 3          Brazil            German
# 4          Brazil  Indian Languages
# 5          Brazil           Italian
# 6          Brazil          Japanese
# 7           Chile            Aimara
# 8           Chile           Araucan
# 9           Chile          Rapa nui
# 10       Colombia          Arawakan
# 11       Colombia         Caribbean
# 12       Colombia           Chibcha
# 13       Colombia    Creole English
# 14        Ecuador            Ketsua
# 15  French Guiana     Creole French
# 16  French Guiana  Indian Languages
# 17         Guyana          Arawakan
# 18         Guyana         Caribbean
# 19         Guyana    Creole English
# 20       Paraguay            German
# 21       Paraguay        Portuguese
# 22       Suriname             Hindi
# 23       Suriname       Sranantonga
# 24      Venezuela           Goajiro
# 25      Venezuela            Warrau

# %% [markdown]
# # **5.3 Mostrar cuantos países hay en cada continente**

# %%
sentencia_sql = """

select  continent,
        count(*) as cantidad_paises
from    country
group by continent

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#        continent  cantidad_paises
# 0         Africa               58
# 1     Antarctica                5
# 2           Asia               51
# 3         Europe               46
# 4  North America               37
# 5        Oceania               28
# 6  South America               14

# %% [markdown]
# # **5.4 Mostrar cuantos idiomas oficinales y no oficiales se hablan en cada país de Europa (en la base de datos se identifica como continente con nombre "Europe")**

# %%
sentencia_sql = """

select  country.name as pais,
        count(*) as cantidad_idiomas
from    country,
        country_language
where   country.code = country_language.country_code
and     country.continent = 'Europe'
group by country.name

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#                              pais  cantidad_idiomas
# 0                         Albania                 3
# 1                         Andorra                 4
# 2                         Austria                 8
# 3                         Belarus                 4
# 4                         Belgium                 6
# 5          Bosnia and Herzegovina                 1
# 6                        Bulgaria                 4
# 7                         Croatia                 2
# 8                  Czech Republic                 8
# 9                         Denmark                 7
# 10                        Estonia                 5
# 11                  Faroe Islands                 2
# 12                        Finland                 5
# 13                         France                 6
# 14                        Germany                 6
# 15                      Gibraltar                 2
# 16                         Greece                 2
# 17  Holy See (Vatican City State)                 1
# 18                        Hungary                 6
# 19                        Iceland                 2
# 20                        Ireland                 2
# 21                          Italy                 8
# 22                         Latvia                 6
# 23                  Liechtenstein                 3
# 24                      Lithuania                 5
# 25                     Luxembourg                 5
# 26                      Macedonia                 5
# 27                          Malta                 2
# 28                        Moldova                 5
# 29                         Monaco                 4
# 30                    Netherlands                 4
# 31                         Norway                 5
# 32                         Poland                 4
# 33                       Portugal                 1
# 34                        Romania                 6
# 35             Russian Federation                12
# 36                     San Marino                 1
# 37                       Slovakia                 5
# 38                       Slovenia                 3
# 39                          Spain                 4
# 40         Svalbard and Jan Mayen                 2
# 41                         Sweden                 6
# 42                    Switzerland                 4
# 43                        Ukraine                 7
# 44                 United Kingdom                 3
# 45                     Yugoslavia                 6

# %% [markdown]
# # **5.5 Mostrar todos los datos de las ciudades de Noruega con más de 100.000 habitantes**

# %%
sentencia_sql = """

select  city.*
from    city,
        country
where   city.country_code = country.code
and     country.name = 'Norway'
and     city.population > 100000

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#      id       name country_code       district  population
# 0  2807       Oslo          NOR           Oslo      508726
# 1  2808     Bergen          NOR      Hordaland      230948
# 2  2809  Trondheim          NOR  Sor-Trondelag      150166
# 3  2810  Stavanger          NOR       Rogaland      108848
# 4  2811     Baerum          NOR       Akershus      101340

# %% [markdown]
# # **5.6 Mostrar nombre, continente y región de los países cuyo nombre finaliza con "istan"**

# %%
sentencia_sql = """

select  name,
        continent,
        region
from    country
where   name like '%istan'

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#            name continent                     region
# 0   Afghanistan      Asia  Southern and Central Asia
# 1      Pakistan      Asia  Southern and Central Asia
# 2    Tajikistan      Asia  Southern and Central Asia
# 3  Turkmenistan      Asia  Southern and Central Asia
# 4    Uzbekistan      Asia  Southern and Central Asia

# %% [markdown]
# # **6. EJERCICIOS CON COMPLEJIDAD MAS ALTA**
#
# NOTA: Estos ejercicios deben realizarse usando únicamente código SQL. Es decir, no "se vale" usar funciones de Pandas para calcular el resultado.

# %% [markdown]
# # **6.1 Mostrar el nombre del país más poblado del mundo, y su población**

# %%
sentencia_sql = """

select  name,
        population
from    country
where   population = (select max(population) from country)

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#     name  population
# 0  China  1277558000

# %% [markdown]
# # **6.2 Mostrar el nombre del país al cual pertenece la ciudad más poblada**

# %%
sentencia_sql = """

select  country.name as pais,
        city.name as ciudad,
        city.population
from    city,
        country
where   city.country_code = country.code
and     city.population = (select max(population) from city)

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#     pais           ciudad  population
# 0  India  Mumbai (Bombay)    10500000

# %% [markdown]
# # **6.3 Mostrar el porcentaje de la población que habla idiomas no oficiales en cada uno de los países de suramérica**

# %%
sentencia_sql = """

select  country.name as pais,
        sum(case when country_language.is_official = 'F'
                 then country_language.percentage
                 else 0
            end) as porcentaje_no_oficial
from    country,
        country_language
where   country.code = country_language.country_code
and     country.continent = 'South America'
group by country.name

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#                 pais  porcentaje_no_oficial
# 0          Argentina                    2.0
# 1            Bolivia                    0.1
# 2             Brazil                    1.5
# 3              Chile                   10.3
# 4           Colombia                    0.7
# 5            Ecuador                    7.0
# 6   Falkland Islands                    0.0
# 7      French Guiana                   96.2
# 8             Guyana                  100.0
# 9           Paraguay                    4.1
# 10              Peru                    0.0
# 11          Suriname                   81.0
# 12           Uruguay                    0.0
# 13         Venezuela                    0.5

# %% [markdown]
# # **6.4 Mostrar el nombre del idioma más hablado en el mundo**

# %%
sentencia_sql = """

select  country_language.language as idioma,
        sum(country.population * country_language.percentage / 100.0) as hablantes
from    country,
        country_language
where   country.code = country_language.country_code
group by country_language.language
order by hablantes desc
limit 1

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#     idioma     hablantes
# 0  Chinese  1.191844e+09

# %% [markdown]
# # **6.5 Mostrar el nombre de las ciudades de Colombia, ordenadas de forma ascendente por su población**

# %%
sentencia_sql = """

select  city.name as ciudad,
        city.population
from    city,
        country
where   city.country_code = country.code
and     country.name = 'Colombia'
order by city.population asc

"""

df = pd.read_sql(sentencia_sql, conn)
print(df)
# Out:
#                ciudad  population
# 0               Giron       90688
# 1            Sogamoso      107728
# 2              Maicao      108053
# 3           Florencia      108574
# 4               Tunja      109740
# 5                Buga      110699
# 6            Girardot      110963
# 7             Cartago      125884
# 8            Envigado      135848
# 9               Tulua      152488
# 10      Dos Quebradas      159363
# 11    Barrancabermeja      178020
# 12            Popayan      200719
# 13          Sincelejo      220704
# 14      Floridablanca      221913
# 15       Buenaventura      224336
# 16            Palmira      226509
# 17             Itagui      228985
# 18           Monteria      248245
# 19         Valledupar      263247
# 20             Soacha      272058
# 21      Villavicencio      273140
# 22            Armenia      288977
# 23            Soledad      295058
# 24              Neiva      300052
# 25              Pasto      332396
# 26              Bello      333470
# 27          Manizales      337580
# 28        Santa Marta      359147
# 29            Pereira      381725
# 30             Ibague      393664
# 31        Bucaramanga      515555
# 32             Cucuta      606932
# 33          Cartagena      805757
# 34       Barranquilla     1223260
# 35           Medellin     1861265
# 36               Cali     2077386
# 37  Santafe de Bogota     6260862
